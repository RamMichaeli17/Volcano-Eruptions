# %%
### Assigned by ###
# Gal Israeli #####
# Yulia Kuderko ###
# Ram Michaeli ####
###################

import os
import re
import sys
import time
import warnings
from datetime import datetime as dt

import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium import webdriver

# ignore warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1st Crawling

# %%
# the main URL of the website
url = "https://volcano.si.edu/search_eruption.cfm"

# using selenium to press the submit button on the home page (can't be done using beautifulsoup)
driver = webdriver.Chrome(os.path.dirname(sys.executable) + "/chromedriver")
driver.get(url)
driver.find_element_by_id('submit_account').click()

volcanoName = list()
eruptionCertainty = list()
startDate = list()
maxVEI = list()

activityArea = list()
evidenceMethod = list()
stopDate = list()

latitude = list()
longitude = list()
volcanoHeight = list()

country = list()
primaryVolcanoType = list()

population5km = list()
population10km = list()
population30km = list()
population100km = list()

# a dictionary that holds all the start dates for each volcano
dateDict = dict()

# final data frame which will be used for opening the csv file after finishing the crawling process
finalDF = pd.DataFrame()

# creating a folder to hold each page from the site in different csv file
folderName = 'Volcanoes By Page'

# if the folder is absent, create it
if not os.path.exists(folderName):
    os.makedirs(folderName)

print("Crawling Started at: " + str(dt.now()))

# a loop that goes through the website's pages
for page in range(1, 16):
    startPageTime = dt.now()
    print("Now in page: " + str(page))
    try:
        # if the page number ISN'T 1, press the next button (using selenium)
        if page != 1:
            driver.find_element_by_xpath("//*[@id='content']/div/div[3]/ul/li[17]/a").click()
    # if the above fails, wait for 2 seconds, reload the driver and press the submit button
    except:
        time.sleep(2)
        driver = webdriver.Chrome(os.path.dirname(sys.executable) + "/chromedriver")
        driver.get(url)
        driver.find_element_by_id('submit_account').click()
        # go back to the last page that was loaded before the failure
        for i in range(1, page):
            driver.find_element_by_xpath("//*[@id='content']/div/div[3]/ul/li[17]/a").click()

    myPage = driver.page_source
    soup = BeautifulSoup(myPage, 'html.parser')
    myTable = soup.find(class_='TableSearchResults')

    # counter that helps us to show the current volcano's name index
    counter = (page - 1) * 750
    # going through the table's rows (while passing over "tHead")
    
    for row in myTable("tr")[1:]:
        if (counter - 25) % 25 == 0:
            startCrawlTime = dt.now()
        counter += 1
        cell = row("td")
        if counter % 25 == 0:
            print("Now At: " + cell[0].text + " number " + str(counter) + " and in page: " + str(page))
        # adding volcano name, eruption certainty, eruption date and max VEI to separate lists
        volcanoName.append(cell[0].text)
        eruptionCertainty.append(cell[1].text)
        startDate.append(cell[2].text)
        maxVEI.append(cell[3].text)

        # reaching the detailed page of each volcano using its specific link
        mainLink = " http://volcano.si.edu" + cell[0]("a")[0]["href"]

        # reaching the "eruptive history" tab
        link_eruptive_history = mainLink + "&vtab=Eruptions"

        newPage = requests.get(link_eruptive_history)

        # as long as the status code of the page isn't 200, wait for 5 seconds and request a
        # permission to access the link
        while newPage.status_code != 200:
            time.sleep(5)
            newPage = requests.get(link_eruptive_history)

        innerSoup = BeautifulSoup(newPage.content, 'html.parser')

        innerTable = innerSoup.find("table", {"class": "DivTable", "title": "Eruption history table for this volcano"})

        innerStartDateArray = list()

        if cell[0].text != 'Unknown Source':
            volcanoID = innerSoup.find(class_='volcano-subinfo-table')("ul")[0]("li")[5].text
        else:
            volcanoID = ''


        # a flag that indicates if the date in the outer table is contained in the date in the inner table
        # if so, change the flag to 1, if not, it means that the start date was not found inside the "Eruption history table for this volcano"
        # so we will set the innerTable to None so afterwards empty cells will be added to the data
        flag = 0

        # create a dictionary that stores the volcano name and its start day array
        # we are using this dictionary to prevent the filling of the same array multiple times
        if cell[0].text+" "+volcanoID not in dateDict:
            if innerTable is not None:
                for index_row in innerTable("tr")[1:]:
                    innerStartDateArray.append(index_row("td")[0].text)
            dateDict[cell[0].text+ " " + volcanoID] = innerStartDateArray

        for index, start_date in enumerate(dateDict[cell[0].text+ " " + volcanoID]):
            if cell[2].text in start_date:
                flag = 1
                break

        if flag == 0:
            innerTable = None

        # increase the index by 1 to skip "<tr>" head
        index += 1

        # try to append the values we want, if not succeed append an empty value in order to keep the sequence
        if innerTable is not None:
            activityArea.append(innerTable("tr")[index]("td")[5].text)
            evidenceMethod.append(innerTable("tr")[index]("td")[4].text)
            stopDate.append(innerTable("tr")[index]("td")[1].text)

            innerTable = innerSoup.find(class_='volcano-subinfo-table')

            # change south and west to minus in latitude and longitude
            if re.sub("[^a-z^A-Z]", "", innerTable("ul")[0]("li")[0].text) == 'S':
                newNum = '-' + (re.sub("[^0-9\.]", "", innerTable("ul")[0]("li")[0].text))

            else:
                newNum = (re.sub("[^0-9\.]", "", innerTable("ul")[0]("li")[0].text))

            latitude.append(newNum)

            if re.sub("[^a-z^A-Z]", "", innerTable("ul")[0]("li")[1].text) == 'W':
                newNum = '-' + (re.sub("[^0-9\.]", "", innerTable("ul")[0]("li")[1].text))

            else:
                newNum = (re.sub("[^0-9\.]", "", innerTable("ul")[0]("li")[1].text))

            longitude.append(newNum)

            volcanoHeight.append(innerTable("ul")[0]("li")[3].contents[0].text)
            innerTable = innerSoup.find(class_='volcano-info-table')
            country.append(innerTable("ul")[0]("li")[0].text)
            primaryVolcanoType.append(innerTable("ul")[0]("li")[2].text)

            innerTable = innerSoup.find("td", {"class": "DivTable35"})

            # iterating in order to get the wanted table row
            for tr in innerTable("tr"):
                continue

        else:
            activityArea.append("")
            evidenceMethod.append("")
            stopDate.append("")
            latitude.append("")
            longitude.append("")
            volcanoHeight.append("")
            country.append("")
            primaryVolcanoType.append("")

        if innerTable is None:
            tr = None

        try:
            # "tr.contents" may be inconsistent, so we wrap this part with try and except for every value
            # if innerTable is None we don't want to append the "tr" from the previous iteration, so we change "tr" to None too
            population5km.append(tr.contents[3].contents[0].strip())
        except:
            population5km.append("")
        try:
            population10km.append(tr.contents[3].contents[2].strip())
        except:
            population10km.append("")
        try:
            population30km.append(tr.contents[3].contents[4].strip())
        except:
            population30km.append("")
        try:
            population100km.append(tr.contents[3].contents[6].strip())
        except:
            population100km.append("")

        if counter % 25 == 0:
            endCrawlTime = dt.now()
            difference = (endCrawlTime - startCrawlTime)
            total_seconds = difference.total_seconds()
            print("Finished after " + str(round(total_seconds, 2)) + " seconds\n")

    # creating a dictionary from all the lists
    data = {
        'volcanoName': volcanoName,
        'eruptionCertainty': eruptionCertainty,
        'startDate': startDate,
        'maxVEI': maxVEI,
        'activityArea': activityArea,
        'evidenceMethod': evidenceMethod,
        'stopDate': stopDate,
        'latitude': latitude,
        'longitude': longitude,
        'volcanoHeight': volcanoHeight,
        'country': country,
        'primaryVolcanoType': primaryVolcanoType,
        'population5km': population5km,
        'population10km': population10km,
        'population30km': population30km,
        'population100km': population100km
    }
    # create a data frame from the dictionary
    df = pd.DataFrame.from_dict(data)
    ## add current dataframe(page) to the final dataframe
    finalDF = finalDF.append(df)

    # export a csv file to each of the pages (15 overall)
    df.to_csv(folderName + '/' + "Volcano(" + str(page) + ").csv", index=False, encoding='utf-8')

    # cleaning the lists and the dictionary for the next iteration
    for key, value in data.items():
        value.clear()

    # cleaning the dictionary
    data.clear()

    endPageTime = dt.now()
    difference_minutes = (endPageTime - startPageTime)
    total_minutes = (difference_minutes.total_seconds()) / 60
    print("Finished page " + str(page) + " after " + str(round(total_minutes, 2)) + " minutes\n")

# export a csv file to all the pages
finalDF.to_csv("Volcano_Final.csv", index=False, encoding='utf-8')

print("Crawling Ended at: " + str(dt.now()))
# Out:
# Crawling Started at: 2022-01-27 15:41:40.847632
# Now in page: 1
# Now At: Tengger Caldera number 25 and in page: 1
# Finished after 130.05 seconds
#
# Now At: Kavachi number 50 and in page: 1
# Finished after 143.34 seconds
#
# Now At: Colima number 75 and in page: 1
# Finished after 130.57 seconds
#
# Now At: Nishinoshima number 100 and in page: 1
# Finished after 141.05 seconds
#
# Now At: Dempo number 125 and in page: 1
# Finished after 140.25 seconds
#
# Now At: Ebulobo number 150 and in page: 1
# Finished after 145.7 seconds
#
# Now At: Bulusan number 175 and in page: 1
# Finished after 200.11 seconds
#
# Now At: Alaid number 200 and in page: 1
# Finished after 130.7 seconds
#
# Now At: San Cristobal number 225 and in page: 1
# Finished after 119.91 seconds
#
# Now At: Mayon number 250 and in page: 1
# Finished after 139.48 seconds
#
# Now At: Asosan number 275 and in page: 1
# Finished after 162.8 seconds
#
# Now At: Kikai number 300 and in page: 1
# Finished after 118.25 seconds
#
# Now At: Pagan number 325 and in page: 1
# Finished after 140.6 seconds
#
# Now At: Ruiz, Nevado del number 350 and in page: 1
# Finished after 143.4 seconds
#
# Now At: Lengai, Ol Doinyo number 375 and in page: 1
# Finished after 147.68 seconds
#
# Now At: Merapi number 400 and in page: 1
# Finished after 171.24 seconds
#
# Now At: Miyakejima number 425 and in page: 1
# Finished after 149.81 seconds
#
# Now At: Cleveland number 450 and in page: 1
# Finished after 150.91 seconds
#
# Now At: Koryaksky number 475 and in page: 1
# Finished after 115.96 seconds
#
# Now At: Rumble III number 500 and in page: 1
# Finished after 116.39 seconds
#
# Now At: Miyakejima number 525 and in page: 1
# Finished after 130.73 seconds
#
# Now At: Telica number 550 and in page: 1
# Finished after 119.8 seconds
#
# Now At: Bulusan number 575 and in page: 1
# Finished after 117.43 seconds
#
# Now At: Akan number 600 and in page: 1
# Finished after 123.62 seconds
#
# Now At: Fournaise, Piton de la number 625 and in page: 1
# Finished after 140.86 seconds
#
# Now At: Chikurachki number 650 and in page: 1
# Finished after 140.55 seconds
#
# Now At: St. Helens number 675 and in page: 1
# Finished after 147.42 seconds
#
# Now At: Ulawun number 700 and in page: 1
# Finished after 159.95 seconds
#
# Now At: Chillan, Nevados de number 725 and in page: 1
# Finished after 137.63 seconds
#
# Now At: Etna number 750 and in page: 1
# Finished after 129.21 seconds
#
# Finished page 1 after 69.77 minutes
#
# Now in page: 2
# Now At: Sumisujima number 775 and in page: 2
# Finished after 141.4 seconds
#
# Now At: Nyiragongo number 800 and in page: 2
# Finished after 142.42 seconds
#
# Now At: Manam number 825 and in page: 2
# Finished after 141.84 seconds
#
# Now At: Sumisujima number 850 and in page: 2
# Finished after 125.89 seconds
#
# Now At: Saunders number 875 and in page: 2
# Finished after 127.29 seconds
#
# Now At: Tungurahua number 900 and in page: 2
# Finished after 136.42 seconds
#
# Now At: Cameroon number 925 and in page: 2
# Finished after 142.43 seconds
#
# Now At: Nyamulagira number 950 and in page: 2
# Finished after 109.95 seconds
#
# Now At: Axial Seamount number 975 and in page: 2
# Finished after 118.37 seconds
#
# Now At: Krakatau number 1000 and in page: 2
# Finished after 103.68 seconds
#
# Now At: Montagu Island number 1025 and in page: 2
# Finished after 111.9 seconds
#
# Now At: Minami-Hiyoshi number 1050 and in page: 2
# Finished after 89.85 seconds
#
# Now At: Kanaga number 1075 and in page: 2
# Finished after 112.4 seconds
#
# Now At: Dempo number 1100 and in page: 2
# Finished after 130.72 seconds
#
# Now At: Ruapehu number 1125 and in page: 2
# Finished after 182.88 seconds
#
# Now At: Tungurahua number 1150 and in page: 2
# Finished after 91.16 seconds
#
# Now At: Llaima number 1175 and in page: 2
# Finished after 130.82 seconds
#
# Now At: Sumisujima number 1200 and in page: 2
# Finished after 110.45 seconds
#
# Now At: Kavachi number 1225 and in page: 2
# Finished after 129.87 seconds
#
# Now At: Southern EPR-Segment K number 1250 and in page: 2
# Finished after 101.62 seconds
#
# Now At: Redoubt number 1275 and in page: 2
# Finished after 162.2 seconds
#
# Now At: Ebeko number 1300 and in page: 2
# Finished after 138.6 seconds
#
# Now At: Banda Api number 1325 and in page: 2
# Finished after 121.24 seconds
#
# Now At: Pagan number 1350 and in page: 2
# Finished after 127.01 seconds
#
# Now At: Kupreanof number 1375 and in page: 2
# Finished after 123.44 seconds
#
# Now At: Cleft Segment number 1400 and in page: 2
# Finished after 123.63 seconds
#
# Now At: Lokon-Empung number 1425 and in page: 2
# Finished after 100.16 seconds
#
# Now At: Raung number 1450 and in page: 2
# Finished after 134.26 seconds
#
# Now At: Lascar number 1475 and in page: 2
# Finished after 150.74 seconds
#
# Now At: Rincon de la Vieja number 1500 and in page: 2
# Finished after 153.72 seconds
#
# Finished page 2 after 63.79 minutes
#
# Now in page: 3
# Now At: Kita-Ioto number 1525 and in page: 3
# Finished after 135.64 seconds
#
# Now At: Fukujin number 1550 and in page: 3
# Finished after 147.31 seconds
#
# Now At: Nishinoshima number 1575 and in page: 3
# Finished after 150.49 seconds
#
# Now At: Guagua Pichincha number 1600 and in page: 3
# Finished after 102.57 seconds
#
# Now At: Klyuchevskoy number 1625 and in page: 3
# Finished after 152.05 seconds
#
# Now At: Akutan number 1650 and in page: 3
# Finished after 131.18 seconds
#
# Now At: Ahyi number 1675 and in page: 3
# Finished after 150.89 seconds
#
# Now At: Carran-Los Venados number 1700 and in page: 3
# Finished after 111.01 seconds
#
# Now At: Krakatau number 1725 and in page: 3
# Finished after 124.03 seconds
#
# Now At: Sumisujima number 1750 and in page: 3
# Finished after 125.88 seconds
#
# Now At: Seguam number 1775 and in page: 3
# Finished after 153.76 seconds
#
# Now At: Fukujin number 1800 and in page: 3
# Finished after 118.53 seconds
#
# Now At: Kasuga 1 number 1825 and in page: 3
# Finished after 122.48 seconds
#
# Now At: Etna number 1850 and in page: 3
# Finished after 124.89 seconds
#
# Now At: Raung number 1875 and in page: 3
# Finished after 170.14 seconds
#
# Now At: Kilauea number 1900 and in page: 3
# Finished after 125.85 seconds
#
# Now At: Epi number 1925 and in page: 3
# Finished after 128.06 seconds
#
# Now At: Paluweh number 1950 and in page: 3
# Finished after 109.87 seconds
#
# Now At: Ambrym number 1975 and in page: 3
# Finished after 116.2 seconds
#
# Now At: Rocard number 2000 and in page: 3
# Finished after 128.68 seconds
#
# Now At: Langila number 2025 and in page: 3
# Finished after 163.01 seconds
#
# Now At: Klyuchevskoy number 2050 and in page: 3
# Finished after 96.93 seconds
#
# Now At: Klyuchevskoy number 2075 and in page: 3
# Finished after 132.05 seconds
#
# Now At: Izu-Oshima number 2100 and in page: 3
# Finished after 140.24 seconds
#
# Now At: Poas number 2125 and in page: 3
# Finished after 126.33 seconds
#
# Now At: Karangetang number 2150 and in page: 3
# Finished after 97.34 seconds
#
# Now At: Slamet number 2175 and in page: 3
# Finished after 122.58 seconds
#
# Now At: Fuego number 2200 and in page: 3
# Finished after 124.85 seconds
#
# Now At: Pavlof number 2225 and in page: 3
# Finished after 113.55 seconds
#
# Now At: Lokon-Empung number 2250 and in page: 3
# Finished after 138.99 seconds
#
# Finished page 3 after 64.85 minutes
#
# Now in page: 4
# Now At: San Miguel number 2275 and in page: 4
# Finished after 144.94 seconds
#
# Now At: Paluweh number 2300 and in page: 4
# Finished after 113.48 seconds
#
# Now At: Lopevi number 2325 and in page: 4
# Finished after 159.29 seconds
#
# Now At: Miyakejima number 2350 and in page: 4
# Finished after 154.2 seconds
#
# Now At: Telica number 2375 and in page: 4
# Finished after 106.7 seconds
#
# Now At: Tupungatito number 2400 and in page: 4
# Finished after 264.54 seconds
#
# Now At: Ambrym number 2425 and in page: 4
# Finished after 142.89 seconds
#
# Now At: Sirung number 2450 and in page: 4
# Finished after 137.64 seconds
#
# Now At: Zhupanovsky number 2475 and in page: 4
# Finished after 144.38 seconds
#
# Now At: Whakaari/White Island number 2500 and in page: 4
# Finished after 130.45 seconds
#
# Now At: Poas number 2525 and in page: 4
# Finished after 113.73 seconds
#
# Now At: Negro, Cerro number 2550 and in page: 4
# Finished after 138.41 seconds
#
# Now At: Akan number 2575 and in page: 4
# Finished after 120.12 seconds
#
# Now At: Tengger Caldera number 2600 and in page: 4
# Finished after 153.83 seconds
#
# Now At: Tolbachik number 2625 and in page: 4
# Finished after 148.84 seconds
#
# Now At: Whakaari/White Island number 2650 and in page: 4
# Finished after 184.41 seconds
#
# Now At: Asosan number 2675 and in page: 4
# Finished after 138.36 seconds
#
# Now At: Rinjani number 2700 and in page: 4
# Finished after 108.65 seconds
#
# Now At: Long Island number 2725 and in page: 4
# Finished after 147.6 seconds
#
# Now At: Myojinsho number 2750 and in page: 4
# Finished after 142.21 seconds
#
# Now At: Poas number 2775 and in page: 4
# Finished after 117.33 seconds
#
# Now At: Farallon de Pajaros number 2800 and in page: 4
# Finished after 147.96 seconds
#
# Now At: Shishaldin number 2825 and in page: 4
# Finished after 97.84 seconds
#
# Now At: Gareloi number 2850 and in page: 4
# Finished after 130.15 seconds
#
# Now At: Marapi number 2875 and in page: 4
# Finished after 148.19 seconds
#
# Now At: Mauna Loa number 2900 and in page: 4
# Finished after 125.51 seconds
#
# Now At: Akutan number 2925 and in page: 4
# Finished after 123.98 seconds
#
# Now At: Asosan number 2950 and in page: 4
# Finished after 137.31 seconds
#
# Now At: Kurikomayama number 2975 and in page: 4
# Finished after 180.51 seconds
#
# Now At: Semeru number 3000 and in page: 4
# Finished after 140.64 seconds
#
# Finished page 4 after 70.8 minutes
#
# Now in page: 5
# Now At: Bagana number 3025 and in page: 5
# Finished after 153.34 seconds
#
# Now At: Krakatau number 3050 and in page: 5
# Finished after 118.9 seconds
#
# Now At: Marapi number 3075 and in page: 5
# Finished after 145.38 seconds
#
# Now At: Etna number 3100 and in page: 5
# Finished after 161.36 seconds
#
# Now At: Miyakejima number 3125 and in page: 5
# Finished after 150.03 seconds
#
# Now At: Dempo number 3150 and in page: 5
# Finished after 150.73 seconds
#
# Now At: Irazu number 3175 and in page: 5
# Finished after 136.21 seconds
#
# Now At: Nemo Peak number 3200 and in page: 5
# Finished after 112.2 seconds
#
# Now At: Cleveland number 3225 and in page: 5
# Finished after 123.13 seconds
#
# Now At: Llaima number 3250 and in page: 5
# Finished after 122.84 seconds
#
# Now At: Bam number 3275 and in page: 5
# Finished after 125.58 seconds
#
# Now At: Etna number 3300 and in page: 5
# Finished after 136.05 seconds
#
# Now At: Sangay number 3325 and in page: 5
# Finished after 179.0 seconds
#
# Now At: Izalco number 3350 and in page: 5
# Finished after 111.8 seconds
#
# Now At: Asamayama number 3375 and in page: 5
# Finished after 112.54 seconds
#
# Now At: Slamet number 3400 and in page: 5
# Finished after 112.79 seconds
#
# Now At: Shikotsu number 3425 and in page: 5
# Finished after 142.24 seconds
#
# Now At: Kilauea number 3450 and in page: 5
# Finished after 152.99 seconds
#
# Now At: Puntiagudo-Cordon Cenizos number 3475 and in page: 5
# Finished after 144.67 seconds
#
# Now At: Slamet number 3500 and in page: 5
# Finished after 112.85 seconds
#
# Now At: Perbakti-Gagak number 3525 and in page: 5
# Finished after 125.03 seconds
#
# Now At: Sheveluch number 3550 and in page: 5
# Finished after 160.11 seconds
#
# Now At: Telica number 3575 and in page: 5
# Finished after 132.24 seconds
#
# Now At: Purace number 3600 and in page: 5
# Finished after 119.31 seconds
#
# Now At: Manam number 3625 and in page: 5
# Finished after 162.36 seconds
#
# Now At: Batur number 3650 and in page: 5
# Finished after 138.79 seconds
#
# Now At: Kilauea number 3675 and in page: 5
# Finished after 162.39 seconds
#
# Now At: Etna number 3700 and in page: 5
# Finished after 104.54 seconds
#
# Now At: Zavaritzki Caldera number 3725 and in page: 5
# Finished after 125.2 seconds
#
# Now At: Klyuchevskoy number 3750 and in page: 5
# Finished after 160.15 seconds
#
# Finished page 5 after 68.35 minutes
#
# Now in page: 6
# Now At: Kerinci number 3775 and in page: 6
# Finished after 133.61 seconds
#
# Now At: Witori number 3800 and in page: 6
# Finished after 133.48 seconds
#
# Now At: Asosan number 3825 and in page: 6
# Finished after 128.6 seconds
#
# Now At: Babuyan Claro number 3850 and in page: 6
# Finished after 121.03 seconds
#
# Now At: Sorikmarapi number 3875 and in page: 6
# Finished after 133.61 seconds
#
# Now At: Mauna Loa number 3900 and in page: 6
# Finished after 70.89 seconds
#
# Now At: Merapi number 3925 and in page: 6
# Finished after 114.59 seconds
#
# Now At: Pavlof number 3950 and in page: 6
# Finished after 102.9 seconds
#
# Now At: Ambrym number 3975 and in page: 6
# Finished after 114.63 seconds
#
# Now At: Villarrica number 4000 and in page: 6
# Finished after 95.1 seconds
#
# Now At: Llaima number 4025 and in page: 6
# Finished after 115.13 seconds
#
# Now At: Gamkonora number 4050 and in page: 6
# Finished after 119.62 seconds
#
# Now At: Heard number 4075 and in page: 6
# Finished after 136.64 seconds
#
# Now At: Bagana number 4100 and in page: 6
# Finished after 101.61 seconds
#
# Now At: Whakaari/White Island number 4125 and in page: 6
# Finished after 123.14 seconds
#
# Now At: Karymsky number 4150 and in page: 6
# Finished after 168.55 seconds
#
# Now At: Soputan number 4175 and in page: 6
# Finished after 111.24 seconds
#
# Now At: Chillan, Nevados de number 4200 and in page: 6
# Finished after 117.09 seconds
#
# Now At: Tofua number 4225 and in page: 6
# Finished after 128.51 seconds
#
# Now At: Okataina number 4250 and in page: 6
# Finished after 124.22 seconds
#
# Now At: Teon number 4275 and in page: 6
# Finished after 115.02 seconds
#
# Now At: Nila number 4300 and in page: 6
# Finished after 114.48 seconds
#
# Now At: Ruapehu number 4325 and in page: 6
# Finished after 124.75 seconds
#
# Now At: Kilauea number 4350 and in page: 6
# Finished after 180.53 seconds
#
# Now At: Semeru number 4375 and in page: 6
# Finished after 135.45 seconds
#
# Now At: Nyiragongo number 4400 and in page: 6
# Finished after 130.44 seconds
#
# Now At: Asamayama number 4425 and in page: 6
# Finished after 136.52 seconds
#
# Now At: Reventador number 4450 and in page: 6
# Finished after 120.85 seconds
#
# Now At: Kirishimayama number 4475 and in page: 6
# Finished after 148.72 seconds
#
# Now At: Vestmannaeyjar number 4500 and in page: 6
# Finished after 125.67 seconds
#
# Finished page 6 after 62.21 minutes
#
# Now in page: 7
# Now At: Dempo number 4525 and in page: 7
# Finished after 139.12 seconds
#
# Now At: Zaozan [Zaosan] number 4550 and in page: 7
# Finished after 102.47 seconds
#
# Now At: Mayon number 4575 and in page: 7
# Finished after 141.47 seconds
#
# Now At: Awu number 4600 and in page: 7
# Finished after 117.38 seconds
#
# Now At: Etna number 4625 and in page: 7
# Finished after 135.81 seconds
#
# Now At: Ushkovsky number 4650 and in page: 7
# Finished after 102.16 seconds
#
# Now At: Galeras number 4675 and in page: 7
# Finished after 101.37 seconds
#
# Now At: Etna number 4700 and in page: 7
# Finished after 133.76 seconds
#
# Now At: Semeru number 4725 and in page: 7
# Finished after 93.07 seconds
#
# Now At: Whakaari/White Island number 4750 and in page: 7
# Finished after 139.3 seconds
#
# Now At: Mayon number 4775 and in page: 7
# Finished after 120.54 seconds
#
# Now At: Irazu number 4800 and in page: 7
# Finished after 132.93 seconds
#
# Now At: Etna number 4825 and in page: 7
# Finished after 125.3 seconds
#
# Now At: Tongariro number 4850 and in page: 7
# Finished after 115.16 seconds
#
# Now At: Momotombo number 4875 and in page: 7
# Finished after 128.44 seconds
#
# Now At: Izalco number 4900 and in page: 7
# Finished after 114.88 seconds
#
# Now At: Poas number 4925 and in page: 7
# Finished after 122.24 seconds
#
# Now At: Sheveluch number 4950 and in page: 7
# Finished after 127.88 seconds
#
# Now At: Izalco number 4975 and in page: 7
# Finished after 100.41 seconds
#
# Now At: San Pedro-San Pablo number 5000 and in page: 7
# Finished after 125.15 seconds
#
# Now At: Mauna Loa number 5025 and in page: 7
# Finished after 135.61 seconds
#
# Now At: Asosan number 5050 and in page: 7
# Finished after 150.48 seconds
#
# Now At: Erta Ale number 5075 and in page: 7
# Finished after 99.63 seconds
#
# Now At: Ragang number 5100 and in page: 7
# Finished after 123.08 seconds
#
# Now At: Raoul Island number 5125 and in page: 7
# Finished after 93.74 seconds
#
# Now At: Maipo number 5150 and in page: 7
# Finished after 101.48 seconds
#
# Now At: Mayon number 5175 and in page: 7
# Finished after 104.91 seconds
#
# Now At: Negro, Cerro number 5200 and in page: 7
# Finished after 122.39 seconds
#
# Now At: Izalco number 5225 and in page: 7
# Finished after 105.73 seconds
#
# Now At: Savo number 5250 and in page: 7
# Finished after 147.71 seconds
#
# Finished page 7 after 60.13 minutes
#
# Now in page: 8
# Now At: Lopevi number 5275 and in page: 8
# Finished after 110.25 seconds
#
# Now At: Dubbi number 5300 and in page: 8
# Finished after 98.78 seconds
#
# Now At: Lewotobi number 5325 and in page: 8
# Finished after 94.34 seconds
#
# Now At: Fournaise, Piton de la number 5350 and in page: 8
# Finished after 108.23 seconds
#
# Now At: Mauna Loa number 5375 and in page: 8
# Finished after 103.62 seconds
#
# Now At: Fuego number 5400 and in page: 8
# Finished after 107.07 seconds
#
# Now At: Fuego number 5425 and in page: 8
# Finished after 145.01 seconds
#
# Now At: Mauna Loa number 5450 and in page: 8
# Finished after 107.22 seconds
#
# Now At: Makian number 5475 and in page: 8
# Finished after 106.75 seconds
#
# Now At: Villarrica number 5500 and in page: 8
# Finished after 100.92 seconds
#
# Now At: Klyuchevskoy number 5525 and in page: 8
# Finished after 120.28 seconds
#
# Now At: Cotopaxi number 5550 and in page: 8
# Finished after 134.5 seconds
#
# Now At: Harrat Ash Shaam number 5575 and in page: 8
# Finished after 99.88 seconds
#
# Now At: Guntur number 5600 and in page: 8
# Finished after 111.46 seconds
#
# Now At: Purace number 5625 and in page: 8
# Finished after 109.04 seconds
#
# Now At: Nasudake number 5650 and in page: 8
# Finished after 89.64 seconds
#
# Now At: Ruiz, Nevado del number 5675 and in page: 8
# Finished after 107.42 seconds
#
# Now At: Makushin number 5700 and in page: 8
# Finished after 131.12 seconds
#
# Now At: Chirippusan [Chirip] number 5725 and in page: 8
# Finished after 112.33 seconds
#
# Now At: Suretamatai number 5750 and in page: 8
# Finished after 130.93 seconds
#
# Now At: Mayon number 5775 and in page: 8
# Finished after 104.16 seconds
#
# Now At: Osorno number 5800 and in page: 8
# Finished after 118.32 seconds
#
# Now At: Banua Wuhu number 5825 and in page: 8
# Finished after 100.54 seconds
#
# Now At: Ragang number 5850 and in page: 8
# Finished after 76.3 seconds
#
# Now At: Fournaise, Piton de la number 5875 and in page: 8
# Finished after 110.83 seconds
#
# Now At: Asosan number 5900 and in page: 8
# Finished after 114.53 seconds
#
# Now At: Klyuchevskoy number 5925 and in page: 8
# Finished after 115.75 seconds
#
# Now At: Matthew Island number 5950 and in page: 8
# Finished after 106.83 seconds
#
# Now At: Opala number 5975 and in page: 8
# Finished after 100.12 seconds
#
# Now At: Isanotski number 6000 and in page: 8
# Finished after 114.28 seconds
#
# Finished page 8 after 54.94 minutes
#
# Now in page: 9
# Now At: Yunaska number 6025 and in page: 9
# Finished after 99.87 seconds
#
# Now At: Toya number 6050 and in page: 9
# Finished after 160.43 seconds
#
# Now At: Fournaise, Piton de la number 6075 and in page: 9
# Finished after 127.65 seconds
#
# Now At: Redoubt number 6100 and in page: 9
# Finished after 100.24 seconds
#
# Now At: Banda Api number 6125 and in page: 9
# Finished after 103.08 seconds
#
# Now At: Fournaise, Piton de la number 6150 and in page: 9
# Finished after 136.02 seconds
#
# Now At: Chirpoi number 6175 and in page: 9
# Finished after 143.01 seconds
#
# Now At: Guntur number 6200 and in page: 9
# Finished after 106.18 seconds
#
# Now At: Tengger Caldera number 6225 and in page: 9
# Finished after 124.12 seconds
#
# Now At: Mayon number 6250 and in page: 9
# Finished after 130.18 seconds
#
# Now At: San Miguel number 6275 and in page: 9
# Finished after 106.48 seconds
#
# Now At: Colima number 6300 and in page: 9
# Finished after 115.05 seconds
#
# Now At: Baker number 6325 and in page: 9
# Finished after 123.44 seconds
#
# Now At: Iwakisan number 6350 and in page: 9
# Finished after 148.46 seconds
#
# Now At: Avachinsky number 6375 and in page: 9
# Finished after 111.99 seconds
#
# Now At: Vulcano number 6400 and in page: 9
# Finished after 121.83 seconds
#
# Now At: Reykjanes number 6425 and in page: 9
# Finished after 123.69 seconds
#
# Now At: Kolokol Group number 6450 and in page: 9
# Finished after 92.83 seconds
#
# Now At: Etna number 6475 and in page: 9
# Finished after 105.84 seconds
#
# Now At: Unnamed number 6500 and in page: 9
# Finished after 118.69 seconds
#
# Now At: Karymsky number 6525 and in page: 9
# Finished after 149.94 seconds
#
# Now At: Kirishimayama number 6550 and in page: 9
# Finished after 127.99 seconds
#
# Now At: Asosan number 6575 and in page: 9
# Finished after 162.12 seconds
#
# Now At: Romanche Fracture Zone number 6600 and in page: 9
# Finished after 165.92 seconds
#
# Now At: Aira number 6625 and in page: 9
# Finished after 152.8 seconds
#
# Now At: Planchon-Peteroa number 6650 and in page: 9
# Finished after 130.13 seconds
#
# Now At: Gede-Pangrango number 6675 and in page: 9
# Finished after 139.8 seconds
#
# Now At: Tolbachik number 6700 and in page: 9
# Finished after 110.76 seconds
#
# Now At: Fournaise, Piton de la number 6725 and in page: 9
# Finished after 112.93 seconds
#
# Now At: Kverkfjoll number 6750 and in page: 9
# Finished after 136.17 seconds
#
# Finished page 9 after 63.23 minutes
#
# Now in page: 10
# Now At: Asamayama number 6775 and in page: 10
# Finished after 113.8 seconds
#
# Now At: Asamayama number 6800 and in page: 10
# Finished after 123.5 seconds
#
# Now At: Banda Api number 6825 and in page: 10
# Finished after 134.82 seconds
#
# Now At: Asosan number 6850 and in page: 10
# Finished after 114.73 seconds
#
# Now At: Etna number 6875 and in page: 10
# Finished after 145.99 seconds
#
# Now At: Ciremai number 6900 and in page: 10
# Finished after 111.96 seconds
#
# Now At: Liamuiga number 6925 and in page: 10
# Finished after 107.64 seconds
#
# Now At: Pacaya number 6950 and in page: 10
# Finished after 127.86 seconds
#
# Now At: Tangkoko-Duasudara number 6975 and in page: 10
# Finished after 124.88 seconds
#
# Now At: Merapi number 7000 and in page: 10
# Finished after 147.89 seconds
#
# Now At: Asosan number 7025 and in page: 10
# Finished after 165.29 seconds
#
# Now At: Quilotoa number 7050 and in page: 10
# Finished after 131.58 seconds
#
# Now At: Asamayama number 7075 and in page: 10
# Finished after 81.88 seconds
#
# Now At: Hualalai number 7100 and in page: 10
# Finished after 122.1 seconds
#
# Now At: La Palma number 7125 and in page: 10
# Finished after 124.48 seconds
#
# Now At: Hakusan number 7150 and in page: 10
# Finished after 125.69 seconds
#
# Now At: Gamalama number 7175 and in page: 10
# Finished after 104.59 seconds
#
# Now At: Vulcano number 7200 and in page: 10
# Finished after 102.5 seconds
#
# Now At: Galeras number 7225 and in page: 10
# Finished after 274.88 seconds
#
# Now At: Asosan number 7250 and in page: 10
# Finished after 130.09 seconds
#
# Now At: Iwakisan number 7275 and in page: 10
# Finished after 134.42 seconds
#
# Now At: Kirishimayama number 7300 and in page: 10
# Finished after 123.58 seconds
#
# Now At: Asamayama number 7325 and in page: 10
# Finished after 130.84 seconds
#
# Now At: Asosan number 7350 and in page: 10
# Finished after 164.53 seconds
#
# Now At: Guagua Pichincha number 7375 and in page: 10
# Finished after 160.92 seconds
#
# Now At: Mombacho number 7400 and in page: 10
# Finished after 164.58 seconds
#
# Now At: Colima number 7425 and in page: 10
# Finished after 137.13 seconds
#
# Now At: Masaya number 7450 and in page: 10
# Finished after 141.13 seconds
#
# Now At: Fernandina number 7475 and in page: 10
# Finished after 100.51 seconds
#
# Now At: Etna number 7500 and in page: 10
# Finished after 154.02 seconds
#
# Finished page 10 after 67.2 minutes
#
# Now in page: 11
# Now At: Orizaba, Pico de number 7525 and in page: 11
# Finished after 166.55 seconds
#
# Now At: Kirishimayama number 7550 and in page: 11
# Finished after 138.68 seconds
#
# Now At: Seulawah Agam number 7575 and in page: 11
# Finished after 134.23 seconds
#
# Now At: Etna number 7600 and in page: 11
# Finished after 166.9 seconds
#
# Now At: Aira number 7625 and in page: 11
# Finished after 177.25 seconds
#
# Now At: Misti, El number 7650 and in page: 11
# Finished after 127.17 seconds
#
# Now At: Vulcano number 7675 and in page: 11
# Finished after 115.11 seconds
#
# Now At: Kuwae number 7700 and in page: 11
# Finished after 113.58 seconds
#
# Now At: Nemrut Dagi number 7725 and in page: 11
# Finished after 130.58 seconds
#
# Now At: Kelud number 7750 and in page: 11
# Finished after 92.26 seconds
#
# Now At: Chichon, El number 7775 and in page: 11
# Finished after 115.92 seconds
#
# Now At: San Pablo Volcanic Field number 7800 and in page: 11
# Finished after 97.7 seconds
#
# Now At: Hakkodasan number 7825 and in page: 11
# Finished after 126.81 seconds
#
# Now At: Kussharo number 7850 and in page: 11
# Finished after 130.41 seconds
#
# Now At: Black Rock Desert number 7875 and in page: 11
# Finished after 79.12 seconds
#
# Now At: Asosan number 7900 and in page: 11
# Finished after 112.18 seconds
#
# Now At: Izu-Oshima number 7925 and in page: 11
# Finished after 81.17 seconds
#
# Now At: Hekla number 7950 and in page: 11
# Finished after 101.9 seconds
#
# Now At: Etna number 7975 and in page: 11
# Finished after 93.18 seconds
#
# Now At: Furnas number 8000 and in page: 11
# Finished after 96.59 seconds
#
# Now At: Mono Lake Volcanic Field number 8025 and in page: 11
# Finished after 121.94 seconds
#
# Now At: Sete Cidades number 8050 and in page: 11
# Finished after 130.38 seconds
#
# Now At: Etna number 8075 and in page: 11
# Finished after 74.36 seconds
#
# Now At: Mauna Loa number 8100 and in page: 11
# Finished after 105.72 seconds
#
# Now At: Halla number 8125 and in page: 11
# Finished after 108.05 seconds
#
# Now At: Niigata-Yakeyama number 8150 and in page: 11
# Finished after 83.9 seconds
#
# Now At: Adams number 8175 and in page: 11
# Finished after 110.65 seconds
#
# Now At: Izu-Oshima number 8200 and in page: 11
# Finished after 80.46 seconds
#
# Now At: La Palma number 8225 and in page: 11
# Finished after 95.09 seconds
#
# Now At: Cayambe number 8250 and in page: 11
# Finished after 112.6 seconds
#
# Finished page 11 after 57.15 minutes
#
# Now in page: 12
# Now At: Chokaisan number 8275 and in page: 12
# Finished after 102.69 seconds
#
# Now At: Kirishimayama number 8300 and in page: 12
# Finished after 90.02 seconds
#
# Now At: Niigata-Yakeyama number 8325 and in page: 12
# Finished after 80.24 seconds
#
# Now At: Chichon, El number 8350 and in page: 12
# Finished after 89.3 seconds
#
# Now At: Machin number 8375 and in page: 12
# Finished after 114.54 seconds
#
# Now At: Hakusan number 8400 and in page: 12
# Finished after 116.27 seconds
#
# Now At: Rabaul number 8425 and in page: 12
# Finished after 99.73 seconds
#
# Now At: Turrialba number 8450 and in page: 12
# Finished after 109.98 seconds
#
# Now At: Bezymianny number 8475 and in page: 12
# Finished after 129.41 seconds
#
# Now At: Mauna Loa number 8500 and in page: 12
# Finished after 121.32 seconds
#
# Now At: Redoubt number 8525 and in page: 12
# Finished after 120.72 seconds
#
# Now At: Tungurahua number 8550 and in page: 12
# Finished after 107.61 seconds
#
# Now At: Osorno number 8575 and in page: 12
# Finished after 112.47 seconds
#
# Now At: Kikai number 8600 and in page: 12
# Finished after 145.24 seconds
#
# Now At: Tungurahua number 8625 and in page: 12
# Finished after 98.46 seconds
#
# Now At: Parinacota number 8650 and in page: 12
# Finished after 92.77 seconds
#
# Now At: Fujisan number 8675 and in page: 12
# Finished after 86.56 seconds
#
# Now At: Calbuco number 8700 and in page: 12
# Finished after 95.64 seconds
#
# Now At: Chichon, El number 8725 and in page: 12
# Finished after 77.97 seconds
#
# Now At: Ata number 8750 and in page: 12
# Finished after 104.61 seconds
#
# Now At: Tungurahua number 8775 and in page: 12
# Finished after 121.05 seconds
#
# Now At: Etna number 8800 and in page: 12
# Finished after 103.19 seconds
#
# Now At: Santorini number 8825 and in page: 12
# Finished after 87.51 seconds
#
# Now At: Vulcano number 8850 and in page: 12
# Finished after 111.25 seconds
#
# Now At: Shikotsu number 8875 and in page: 12
# Finished after 145.28 seconds
#
# Now At: Leonard Range number 8900 and in page: 12
# Finished after 90.2 seconds
#
# Now At: Tungurahua number 8925 and in page: 12
# Finished after 86.79 seconds
#
# Now At: Muria number 8950 and in page: 12
# Finished after 117.47 seconds
#
# Now At: Reykjanes number 8975 and in page: 12
# Finished after 104.66 seconds
#
# Now At: Rainier number 9000 and in page: 12
# Finished after 91.09 seconds
#
# Finished page 12 after 52.71 minutes
#
# Now in page: 13
# Now At: Adams number 9025 and in page: 13
# Finished after 105.67 seconds
#
# Now At: Khangar number 9050 and in page: 13
# Finished after 99.96 seconds
#
# Now At: Matutum number 9075 and in page: 13
# Finished after 76.76 seconds
#
# Now At: Mutnovsky number 9100 and in page: 13
# Finished after 109.54 seconds
#
# Now At: Tenerife number 9125 and in page: 13
# Finished after 112.92 seconds
#
# Now At: Bakening number 9150 and in page: 13
# Finished after 78.47 seconds
#
# Now At: Pelee number 9175 and in page: 13
# Finished after 69.31 seconds
#
# Now At: Mageik number 9200 and in page: 13
# Finished after 99.78 seconds
#
# Now At: Merapi number 9225 and in page: 13
# Finished after 104.39 seconds
#
# Now At: Myokosan number 9250 and in page: 13
# Finished after 76.63 seconds
#
# Now At: Kilauea number 9275 and in page: 13
# Finished after 92.17 seconds
#
# Now At: Picos Fissural Volcanic System number 9300 and in page: 13
# Finished after 92.15 seconds
#
# Now At: Vulcano number 9325 and in page: 13
# Finished after 71.58 seconds
#
# Now At: Taveuni number 9350 and in page: 13
# Finished after 119.4 seconds
#
# Now At: Yoteizan number 9375 and in page: 13
# Finished after 73.55 seconds
#
# Now At: Kusatsu-Shiranesan number 9400 and in page: 13
# Finished after 107.59 seconds
#
# Now At: Galeras number 9425 and in page: 13
# Finished after 83.9 seconds
#
# Now At: Guagua Pichincha number 9450 and in page: 13
# Finished after 81.26 seconds
#
# Now At: Agua de Pau number 9475 and in page: 13
# Finished after 90.42 seconds
#
# Now At: Koshelev number 9500 and in page: 13
# Finished after 72.0 seconds
#
# Now At: Taveuni number 9525 and in page: 13
# Finished after 100.26 seconds
#
# Now At: Severny number 9550 and in page: 13
# Finished after 111.68 seconds
#
# Now At: Moffett number 9575 and in page: 13
# Finished after 78.54 seconds
#
# Now At: Nemrut Dagi number 9600 and in page: 13
# Finished after 109.95 seconds
#
# Now At: Martin number 9625 and in page: 13
# Finished after 73.8 seconds
#
# Now At: Rincon de la Vieja number 9650 and in page: 13
# Finished after 97.55 seconds
#
# Now At: Hudson, Cerro number 9675 and in page: 13
# Finished after 98.26 seconds
#
# Now At: Savai'i number 9700 and in page: 13
# Finished after 77.15 seconds
#
# Now At: Mayotte number 9725 and in page: 13
# Finished after 84.02 seconds
#
# Now At: Katla number 9750 and in page: 13
# Finished after 92.35 seconds
#
# Finished page 13 after 45.78 minutes
#
# Now in page: 14
# Now At: San Martin number 9775 and in page: 14
# Finished after 94.49 seconds
#
# Now At: Campi Flegrei number 9800 and in page: 14
# Finished after 106.17 seconds
#
# Now At: Pelee number 9825 and in page: 14
# Finished after 70.65 seconds
#
# Now At: Taapaca number 9850 and in page: 14
# Finished after 97.43 seconds
#
# Now At: Avachinsky number 9875 and in page: 14
# Finished after 87.43 seconds
#
# Now At: Craters of the Moon number 9900 and in page: 14
# Finished after 87.64 seconds
#
# Now At: Ata number 9925 and in page: 14
# Finished after 81.06 seconds
#
# Now At: Colima number 9950 and in page: 14
# Finished after 119.58 seconds
#
# Now At: Sheveluch number 9975 and in page: 14
# Finished after 113.95 seconds
#
# Now At: Tskhouk-Karckar number 10000 and in page: 14
# Finished after 74.97 seconds
#
# Now At: Bulusan number 10025 and in page: 14
# Finished after 96.26 seconds
#
# Now At: Arenal number 10050 and in page: 14
# Finished after 100.04 seconds
#
# Now At: Katla number 10075 and in page: 14
# Finished after 101.34 seconds
#
# Now At: Asamayama number 10100 and in page: 14
# Finished after 111.01 seconds
#
# Now At: Kurikomayama number 10125 and in page: 14
# Finished after 81.33 seconds
#
# Now At: Taveuni number 10150 and in page: 14
# Finished after 55.31 seconds
#
# Now At: Villarrica number 10175 and in page: 14
# Finished after 95.64 seconds
#
# Now At: Kaguyak number 10200 and in page: 14
# Finished after 74.96 seconds
#
# Now At: Unknown Source number 10225 and in page: 14
# Finished after 75.65 seconds
#
# Now At: Shasta number 10250 and in page: 14
# Finished after 74.48 seconds
#
# Now At: Mikurajima number 10275 and in page: 14
# Finished after 60.44 seconds
#
# Now At: Katla number 10300 and in page: 14
# Finished after 93.24 seconds
#
# Now At: Niijima number 10325 and in page: 14
# Finished after 70.71 seconds
#
# Now At: Puyehue-Cordon Caulle number 10350 and in page: 14
# Finished after 96.16 seconds
#
# Now At: Cherpuk Group number 10375 and in page: 14
# Finished after 82.15 seconds
#
# Now At: Takaharayama number 10400 and in page: 14
# Finished after 64.69 seconds
#
# Now At: Merapi number 10425 and in page: 14
# Finished after 88.5 seconds
#
# Now At: Aira number 10450 and in page: 14
# Finished after 81.05 seconds
#
# Now At: Nemrut Dagi number 10475 and in page: 14
# Finished after 86.65 seconds
#
# Now At: Mikurajima number 10500 and in page: 14
# Finished after 73.58 seconds
#
# Finished page 14 after 43.34 minutes
#
# Now in page: 15
# Now At: Fujisan number 10525 and in page: 15
# Finished after 101.16 seconds
#
# Now At: Redoubt number 10550 and in page: 15
# Finished after 110.02 seconds
#
# Now At: Nejapa-Miraflores number 10575 and in page: 15
# Finished after 84.85 seconds
#
# Now At: Sheveluch number 10600 and in page: 15
# Finished after 85.1 seconds
#
# Now At: Katla number 10625 and in page: 15
# Finished after 70.67 seconds
#
# Now At: Katla number 10650 and in page: 15
# Finished after 60.21 seconds
#
# Now At: Rishirizan number 10675 and in page: 15
# Finished after 84.97 seconds
#
# Now At: Redoubt number 10700 and in page: 15
# Finished after 67.89 seconds
#
# Now At: Vestmannaeyjar number 10725 and in page: 15
# Finished after 85.88 seconds
#
# Now At: Sheveluch number 10750 and in page: 15
# Finished after 82.38 seconds
#
# Now At: Acigol-Nevsehir number 10775 and in page: 15
# Finished after 81.08 seconds
#
# Now At: Lanin number 10800 and in page: 15
# Finished after 96.99 seconds
#
# Now At: Unknown Source number 10825 and in page: 15
# Finished after 135.99 seconds
#
# Now At: Fujisan number 10850 and in page: 15
# Finished after 93.07 seconds
#
# Now At: Orizaba, Pico de number 10875 and in page: 15
# Finished after 109.41 seconds
#
# Now At: Infiernillo number 10900 and in page: 15
# Finished after 93.24 seconds
#
# Now At: Zheltovsky number 10925 and in page: 15
# Finished after 87.47 seconds
#
# Now At: Kujusan number 10950 and in page: 15
# Finished after 94.93 seconds
#
# Now At: Hengill number 10975 and in page: 15
# Finished after 88.81 seconds
#
# Now At: Burney, Monte number 11000 and in page: 15
# Finished after 86.61 seconds
#
# Now At: Maly Semyachik number 11025 and in page: 15
# Finished after 91.68 seconds
#
# Now At: Yojoa, Lago number 11050 and in page: 15
# Finished after 79.71 seconds
#
# Now At: Rainier number 11075 and in page: 15
# Finished after 118.41 seconds
#
# Now At: Unknown Source number 11100 and in page: 15
# Finished after 81.76 seconds
#
# Now At: Kostakan number 11125 and in page: 15
# Finished after 65.85 seconds
#
# Now At: Unknown Source number 11150 and in page: 15
# Finished after 125.26 seconds
#
# Now At: Fujisan number 11175 and in page: 15
# Finished after 91.75 seconds
#
# Now At: Red Hill number 11200 and in page: 15
# Finished after 82.39 seconds
#
# Finished page 15 after 43.46 minutes
#
# Crawling Ended at: 2022-01-28 06:29:24.123804

# %% [markdown]
# # 2nd Crawling

# %%
# the main URL of the website
url = "https://volcano.si.edu/search_emission.cfm"

# using selenium to press the submit button on the home page (can't be done using beautifulsoup)
driver = webdriver.Chrome(os.path.dirname(sys.executable) + "/chromedriver")
driver.get(url)
driver.find_element_by_id('submit_account').click()

volcanoName = list()
startDate = list()
endDate = list()
SO2_Mass_kt = list()
SO2_Altitude = list()

print("Crawling Started at: " + str(dt.now()))

myPage = driver.page_source
soup = BeautifulSoup(myPage, 'html.parser')
myTable = soup.find(class_='TableSearchResults')
# going through the table's rows (while passing over "tHead")

counter = 0
for row in myTable("tr")[1:]:
    counter += 1
    cell = row("td")
    if counter % 10 == 0:
        print("Now At: " + cell[0].text + " number " + str(counter))
    # adding volcano name, start date, end date, SO2 Mass kt and SO2 Altitude to separate lists
    volcanoName.append(cell[0].text)
    startDate.append(cell[2].text)
    endDate.append(cell[3].text)
    SO2_Mass_kt.append(cell[4].text)
    SO2_Altitude.append(cell[5].text)

# creating a dictionary from all the lists
data = {
    'volcanoName': volcanoName,
    'startDate': startDate,
    'endDate': endDate,
    'SO2_Mass_kt': SO2_Mass_kt,
    'SO2_Altitude': SO2_Altitude
}
# create a data frame from the dictionary
df = pd.DataFrame.from_dict(data)

df.to_csv("Volcano_Emission.csv", index=False, encoding='utf-8')

print("Crawling Ended at: " + str(dt.now()))
# Out:
# Crawling Started at: 2022-01-30 03:09:08.466278
# Now At: Fournaise, Piton de la number 10
# Now At: Soputan number 20
# Now At: Pavlof number 30
# Now At: Rabaul number 40
# Now At: Veniaminof number 50
# Now At: Etna number 60
# Now At: Planchon-Peteroa number 70
# Now At: Etna number 80
# Now At: Fournaise, Piton de la number 90
# Now At: Bezymianny number 100
# Now At: Soufriere Hills number 110
# Now At: Etna number 120
# Now At: Soufriere Hills number 130
# Now At: Fourpeaked number 140
# Now At: Tungurahua number 150
# Now At: Negra, Sierra number 160
# Now At: Soputan number 170
# Now At: Fournaise, Piton de la number 180
# Now At: Galeras number 190
# Now At: Fournaise, Piton de la number 200
# Now At: Cleveland number 210
# Now At: Miyakejima number 220
# Now At: Soufriere Hills number 230
# Now At: Rinjani number 240
# Now At: Pinatubo number 250
# Now At: Pacaya number 260
# Now At: Etna number 270
# Now At: Kilauea number 280
# Now At: Ruiz, Nevado del number 290
# Now At: Kilauea number 300
# Now At: Mauna Loa number 310
# Now At: Kilauea number 320
# Now At: Lopevi number 330
# Now At: Pagan number 340
# Now At: St. Helens number 350
# Now At: Ambrym number 360
# Crawling Ended at: 2022-01-30 03:09:08.826772
